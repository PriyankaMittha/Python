# %% [markdown]
# # Operators

# %% [markdown]
# ### Addition operator(+)

# %%
a = 2
b = 4
c = 3.5
d = " hello students"
e = " how are you"
f = 6+5j

# %%
print(a+b)
# Out:
# 6

# %%
print(a+c)
# Out:
# 5.5

# %%
print(a+f)
# Out:
# (8+5j)

# %%
print(c + f)
# Out:
# (9.5+5j)

# %%
print(d+e)
# Out:
#  hello students how are you

# %% [markdown]
# ### Subtract operator(-)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         hello students
# e          str         how are you
# f          complex    (6+5j)

# %%
print(b-a)
# Out:
# 2

# %%
print(b-c)
# Out:
# 0.5

# %%
print(f-a)
# Out:
# (4+5j)

# %%
print(f-c)
# Out:
# (2.5+5j)

# %%
#print(d-e) # string cannot do subtract

# %% [markdown]
# ### Multiplication operator(*)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         hello students
# e          str         how are you
# f          complex    (6+5j)

# %%
print(a * b)
# Out:
# 8

# %%
print(a * c)
# Out:
# 7.0

# %%
print(a * f)
# Out:
# (12+10j)

# %%
print(c * f)
# Out:
# (21+17.5j)

# %%
#print(d * e)  # string cannot multiply

# %% [markdown]
# ### Division operator(/)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         hello students
# e          str         how are you
# f          complex    (6+5j)

# %%
print(b/a)
# Out:
# 2.0

# %%
print(c/a)
# Out:
# 1.75

# %%
print(b/c)
# Out:
# 1.1428571428571428

# %%
print(f/a)
# Out:
# (3+2.5j)

# %%
print(f/c)
# Out:
# (1.7142857142857142+1.4285714285714286j)

# %%
#print(d/e)  # string cannot divide

# %% [markdown]
# ### Modulus operator(%)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         hello students
# e          str         how are you
# f          complex    (6+5j)

# %%
print(b%2)
# Out:
# 0

# %%
print(c%a)
# Out:
# 1.5

# %%
#print(f%a) # complex number can't support modulus

# %% [markdown]
# ### Exponent operator(**)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         hello students
# e          str         how are you
# f          complex    (6+5j)

# %%
print(a**4)
# Out:
# 16

# %%
print(a**b)
# Out:
# 16

# %%
print(c** 18)
# Out:
# 6211904899.255558

# %%
print(c ** b)
# Out:
# 150.0625

# %%
print(f ** 2)
# Out:
# (11+60j)

# %%
print((23 **9) + (56+78) + (123456*1567890) - (23-89.876990))
# Out:
# 1994718089503.877

# %% [markdown]
# ### Floor division(//)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         hello students
# e          str         how are you
# f          complex    (6+5j)

# %%
print(b//a)
# Out:
# 2

# %%
print(c//a)
# Out:
# 1.0

# %%
#print(f//a) # floor cannot support to complex number

# %%
add = a+b
print(add)
# Out:
# 6

# %%
_a = 7

# %%
print(_a)
# Out:
# 7

# %%
_b = 23

# %%
print(_b)
# Out:
# 23

# %% [markdown]
# # Assignment Operator

# %%
m = 15

# %%
m += 10
print(m)
# Out:
# 25

# %%
m = 15
m -= 10
print(m)
# Out:
# 5

# %%
m = 15
m *= 10
print(m)
# Out:
# 150

# %%
m = 15
m /= 10
print(m)
# Out:
# 1.5

# %%
m = 15
m %= 10
print(m)
# Out:
# 5

# %%
m = 15
m **= 2
print(m)
# Out:
# 225

# %%
m = 15
m //= 10
print(m)
# Out:
# 1

# %% [markdown]
# # Logical & Boolean Operators

# %%
a = True
b = True
c = False
d = False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %%
type(c)
# Out:
# bool

# %%
type(d)
# Out:
# bool

# %%
print(a and b)
# Out:
# True

# %%
print(a or b)
# Out:
# True

# %%
print(a and c)
# Out:
# False

# %%
print(c and a)
# Out:
# False

# %%
print(c and d)
# Out:
# False

# %%
print((a and b) and (c and d))
# Out:
# False

# %%
print(a or b)
# Out:
# True

# %%
print(a or c)
# Out:
# True

# %%
print(c or d)
# Out:
# False

# %%
print((a or b) or (c or d) or (d or a))
# Out:
# True

# %%
print(( a and b) or (a or c) and (d and c))
# Out:
# True

# %%
print( not (a))
# Out:
# False

# %%
print(not(c))
# Out:
# True

# %%
print(not ((a and b) or (a or c) and (b and c) or (d or a)))
# Out:
# False

# %%
print( not ((a and c) or (b and d) and (a and b)))
# Out:
# True

# %% [markdown]
# # Comparison Opeators

# %%
c = 2<3
print(c)
# Out:
# True

# %%
type(c)
# Out:
# bool

# %%
d = 2==3
print(d)
# Out:
# False

# %%
3 == 3.0
# Out:
# True

# %%
p = 12
q = 8
r = -3
s = 5.56

# %%
print((q<p) and (r>s))
# Out:
# False

# %%
print(not((p==q) or (r==s)))
# Out:
# True

# %%
print((p>=r) and (r<=s) or (q<=r))
# Out:
# True

# %%
True or False and True
# Out:
# True

# %%
print((not(2!=3) and True) or (False and True))
# Out:
# False

# %% [markdown]
# # Bitwise Opeators

# %%
a = 5
b = 4
print(a&b)
# Out:
# 4

# %%
print(type(a&b))
# Out:
# <class 'int'>

# %%
a = 893874567
b = 125965
print( a & b)
# Out:
# 90117

# %%
a = 4576878789545789
b = 7890999675577890
print( a&b)
# Out:
# 4504151530948128

# %%
a = 5
b = 4
print(a|b)
# Out:
# 5

# %%
a = 6 
b = 8
print(a|b)
# Out:
# 14

# %%
a = 455667889046
b = 565768132455
print(a|b)
# Out:
# 1012537276407

# %%
a = 5
b = 4
print(a^b)
# Out:
# 1

# %%
a = 6 
b = 10
print(a^b)
# Out:
# 12

# %%
a = 987689986
b = 679654439
print(a^b)
# Out:
# 308035621

# %%
a = 5
print(~5)
# Out:
# -6

# %%
a = 10
print(~a)
# Out:
# -11

# %%
a = 456881912
print(~a)
# Out:
# -456881913

# %%
a = 5
print(a<<2)
# Out:
# 20

# %%
a = 7
print(a<<5)
# Out:
# 224

# %%
a = 5
print(a<<5)
# Out:
# 160

# %%
a = 789056
print(a>>2)
# Out:
# 197264

# %%
a = 7
print(a>>3)
# Out:
# 0
