# %% [markdown]
# # User Defined Function

# %% [raw]
# A function that are written by an user comes under the user defined functions.
# A def keyword is used to declare a function.
# An intended block of statements follows the function name and arguments which contains the body of the function

# %%
# syntax
def function_name():
    statements

# %%
def success():
    print("Python is a high level programming language")
    print("Python is easy to learn")
    print("Python is dynamically typed")

# %%
a = 5
b = 6
print(a+b)
success()
m = 15
n = 16
o = 12
print((m*n)+(m-n)+(o*n))
success()
# Out:
# 11
# Python is a high level programming language
# Python is easy to learn
# Python is dynamically typed
# 431
# Python is a high level programming language
# Python is easy to learn
# Python is dynamically typed

# %%
""" Write a program to make a report of a patient calculate the BMI, and take from patient like weight & height, Hb, & do this for 5 patients"""
# Out:
# ' Write a program to make a report of a patient calculate the BMI, and take from patient like weight & height, Hb, & do this for 5 patients'

# %%
def dietplan():
    print("This is your DIET PLAN")
    print("In the breakfast include milk")
    print("In the lunch include some protiens")
    print("In the dinner include some cereals")
    print("do regular excercise")
    print("morning walks are most recommended")

# %%
n = 5
while n<=5:
    w = int(input("Enter your weight:"))
    h = int(input("Enter your height:"))
    wb = int(input("Enter your himoglobin:"))
    BMI = w/h
    print("Patient's BMI is", BMI)
    dietplan()
    print("-------------------------")
    n=n+1
# Out:
# Enter your weight: 56
# Enter your height: 7
# Enter your himoglobin: 8
# Patient's BMI is 8.0
# This is your DIET PLAN
# In the breakfast include milk
# In the lunch include some protiens
# In the dinner include some cereals
# do regular excercise
# morning walks are most recommended
# -------------------------

# %% [markdown]
# # DocString in Python

# %%
def learn():
    """ This function does nothing """
    print("Learn Python")
    print("It is easy")

# %%
learn()
# Out:
# Learn Python
# It is easy

# %%
learn?
# Out:
# Signature: learn()
# Docstring: This function does nothing
# File:      c:\users\pc\appdata\local\temp\ipykernel_10484\2349889262.py
# Type:      function
