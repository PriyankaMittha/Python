# %% [markdown]
# # Variables
# #### variables are containers, which is used to store or hold a value.

# %%
x = 6
print(x)
# Out:
# 6

# %%
type(x)
# Out:
# int

# %%
y = 6.890
print(y)
type(y)
# Out:
# 6.89
# float

# %%
z = 12+3j
print(z)
type(z)
# Out:
# (12+3j)
# complex

# %%
t = "I am learning Python"
print(t)
type(t)
# Out:
# I am learning Python
# str

# %%
o = "Hello students, 23 students are present in the class"
print(o)
type(o)
# Out:
# Hello students, 23 students are present in the class
# str

# %%
# How many variables are there in the notebook
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# X          float      2.34
# a          int        3
# b          float      4.5
# c          str        hello students
# o          str        Hello students, 23 studen<...> are present in the class
# t          str        I am learning Python
# x          int        6
# y          float      6.89
# z          complex    (12+3j)

# %%
del z

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# X          float    2.34
# a          int      3
# b          float    4.5
# c          str      hello students
# o          str      Hello students, 23 studen<...> are present in the class
# t          str      I am learning Python
# x          int      6
# y          float    6.89

# %%
a = 10
b = 12 
c = 14
print(a)
print(b)
print(c)
# Out:
# 10
# 12
# 14

# %% [markdown]
# # Multiple assignmets

# %%
a, b, c = 3,4.5, "hello students"
print(a,b,c)
print(type(a), type(b), type(c))
# Out:
# 3 4.5 hello students
# <class 'int'> <class 'float'> <class 'str'>

# %%
x = 21
X = 2.34
print(x)
# Out:
# 21

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# X          float    2.34
# a          int      3
# b          float    4.5
# c          str      hello students
# o          str      Hello students, 23 studen<...> are present in the class
# t          str      I am learning Python
# x          int      21
# y          float    6.89
